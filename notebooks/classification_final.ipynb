# %%
import pandas as pd
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf


gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU Detected: {gpus[0].name}")
        print("   Memory Growth: Enabled")
    except RuntimeError as e:
        print(e)
else:
    print("No GPU found. Check your installation.")
print(tf.config.list_physical_devices('GPU'))
from tensorflow.keras import mixed_precision
# Out:
# ✅ GPU Detected: /physical_device:GPU:0
#    Memory Growth: Enabled
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from pathlib import Path
import sys

CURRENT_DIR = Path().resolve()

if (CURRENT_DIR / "src").exists():
    PROJECT_ROOT = CURRENT_DIR
elif (CURRENT_DIR.parent / "src").exists():
    PROJECT_ROOT = CURRENT_DIR.parent
else:
    raise RuntimeError("Cannot find src directory from notebook")

sys.path.append(str(PROJECT_ROOT))
print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PROJECT_ROOT: /home/oleksandr/ind1_deeplearning

# %%
# from src.models import get_model
# from src.data import load_train_val_from_directory
# from src.ButterflyTrainer import ButterflyTrainer # Assuming file is src/trainer.py
# from src.config_schema import ModelConfig, TrainConfig
# from src.augmentation import get_augment_layer 
# batch_size = 64

# train_config = TrainConfig(
#     epochs=30,
#     batch_size=batch_size,
#     learning_rate=3e-4,
#     use_mlflow=True
# )

# model_config = ModelConfig(
#     model_name="alexnet",
#     input_shape=(224, 224, 3),
#     num_classes=100,
#     dropout_rate=0.5,

#     augmentation_layer=get_augment_layer() 
# )

# print("Loading Data...")
# train_ds, val_ds, _ = load_train_val_from_directory(
#     batch_size=train_config.batch_size
# )

# print("Creating AlexNet...")

# model = get_model(
#                   model_name=model_config.model_name,
#                   input_shape=model_config.input_shape,
#                   num_classes=model_config.num_classes,
#                   dropout_rate=model_config.dropout_rate,
#                   augmentation_layer=model_config.augmentation_layer
#                  )

# print("Starting Training...")
# trainer = ButterflyTrainer(model, train_ds, val_ds, train_config)
# trainer.compile()
# history = trainer.train()
# Out:
# /home/oleksandr/ind1_deeplearning/venv/lib/python3.12/site-packages/tensorflow_hub/__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# 2025/11/28 00:59:40 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/11/28 00:59:40 INFO mlflow.store.db.utils: Updating database tables
# 2025-11-28 00:59:40 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-11-28 00:59:40 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025-11-28 00:59:40 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-11-28 00:59:40 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# ✅ MLflow setup complete. Tracking to: sqlite:////home/oleksandr/ind1_deeplearning/mlflow.db
# ...

# %%
# from src.models import get_model
# from src.data import load_train_val_from_directory
# from src.ButterflyTrainer import ButterflyTrainer # Assuming file is src/trainer.py
# from src.config_schema import ModelConfig, TrainConfig
# from src.augmentation import get_augment_layer 
# batch_size = 64

# train_config = TrainConfig(
#     epochs=30,
#     batch_size=batch_size,
#     learning_rate=3e-4,
#     use_mlflow=True
# )

# model_config = ModelConfig(
#     model_name="convnext_base",
#     input_shape=(224, 224, 3),
#     num_classes=100,
#     dropout_rate=0.4,

#     augmentation_layer=get_augment_layer() 
# )

# print("Loading Data...")
# train_ds, val_ds, _ = load_train_val_from_directory(
#     batch_size=train_config.batch_size
# )

# print("Creating ConvNeXt Base...")

# model = get_model(
#                   model_name=model_config.model_name,
#                   input_shape=model_config.input_shape,
#                   num_classes=model_config.num_classes,
#                   dropout_rate=model_config.dropout_rate,
#                   augmentation_layer=model_config.augmentation_layer
#                  )

# print("Starting Training...")
# trainer = ButterflyTrainer(model, train_ds, val_ds, train_config)
# trainer.compile()
# history = trainer.train()

# %%
# from src.models import get_model
# from src.data import load_train_val_from_directory
# from src.ButterflyTrainer import ButterflyTrainer # Assuming file is src/trainer.py
# from src.config_schema import ModelConfig, TrainConfig
# from src.augmentation import get_augment_layer 
# batch_size = 128

# train_config = TrainConfig(
#     epochs=30,
#     batch_size=batch_size,
#     learning_rate=3e-4,
#     use_mlflow=True
# )

# model_config = ModelConfig(
#     model_name="convnext_base",
#     input_shape=(224, 224, 3),
#     num_classes=100,
#     dropout_rate=0.5,

#     augmentation_layer=get_augment_layer() 
# )

# print("Loading Data...")
# train_ds, val_ds, _ = load_train_val_from_directory(
#     batch_size=train_config.batch_size
# )

# print("Creating ConvNeXt Base...")

# model = get_model(
#                   model_name=model_config.model_name,
#                   input_shape=model_config.input_shape,
#                   num_classes=model_config.num_classes,
#                   dropout_rate=model_config.dropout_rate,
#                   augmentation_layer=model_config.augmentation_layer
#                  )

# print("Starting Training...")
# trainer = ButterflyTrainer(model, train_ds, val_ds, train_config)
# trainer.compile()
# history = trainer.train()

# %%
from src.models import get_model
from src.data import load_train_val_from_directory
from src.ButterflyTrainer import ButterflyTrainer # Assuming file is src/trainer.py
from src.config_schema import ModelConfig, TrainConfig
from src.augmentation import get_augment_layer 
batch_size = 32

train_config = TrainConfig(
    epochs=30,
    batch_size=batch_size,
    learning_rate=4e-4,
    use_mlflow=True
)

model_config = ModelConfig(
    model_name="convnext_base",
    input_shape=(224, 224, 3),
    num_classes=100,
    dropout_rate=0.1,

    augmentation_layer=get_augment_layer() 
)

print("Loading Data...")
train_ds, val_ds, _ = load_train_val_from_directory(
    batch_size=train_config.batch_size
)

print("Creating ConvNeXt Base...")

model = get_model(
                  model_name=model_config.model_name,
                  input_shape=model_config.input_shape,
                  num_classes=model_config.num_classes,
                  dropout_rate=model_config.dropout_rate,
                  augmentation_layer=model_config.augmentation_layer
                 )

print("Starting Training...")
trainer = ButterflyTrainer(model, train_ds, val_ds, train_config)
trainer.compile()
history = trainer.train()
# Out:
# /home/oleksandr/ind1_deeplearning/venv/lib/python3.12/site-packages/tensorflow_hub/__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764278181.232124 1316559 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5561 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-11-27 21:16:21.372435: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# Loading Data...
# Creating ConvNeXt Base...
# ...

# %%
model.save('../models/convexnet_base2_version_01drop.keras')

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.utils import load_img, img_to_array


generate_submission(
    model_path='../models/convexnet_base2_version_01drop.keras',
    test_csv_path='../data/test.csv',
    images_root_dir='../data/',
    class_names_path='../data/classes.txt',
    output_path='submissionb_convexnet2_dop.csv',
    batch_size=32,
    image_size=(224, 224)
)
# Out:
# Starting predictions on 2728 images...
# 2025-11-27 21:52:09.197684: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-27 21:52:09.361424: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-27 21:52:09.509957: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-27 21:52:09.653166: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# ...
